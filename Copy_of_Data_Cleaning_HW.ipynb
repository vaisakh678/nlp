# %%
import pandas as pd

text = "India, officially the Republic of India (Hindi: Bhārat Gaṇarājya),[26] is a country in South Asia. It is the seventh-largest country by area, the second-most populous country, and the most populous democracy in the world. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[f] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia. The nation's capital city is New Delhi."

text=text.lower()

text
# Out:
# "india, officially the republic of india (hindi: bhārat gaṇarājya),[26] is a country in south asia. it is the seventh-largest country by area, the second-most populous country, and the most populous democracy in the world. bounded by the indian ocean on the south, the arabian sea on the southwest, and the bay of bengal on the southeast, it shares land borders with pakistan to the west;[f] china, nepal, and bhutan to the north; and bangladesh and myanmar to the east. in the indian ocean, india is in the vicinity of sri lanka and the maldives; its andaman and nicobar islands share a maritime border with thailand, myanmar, and indonesia. the nation's capital city is new delhi."

# %%
#punctuation removal

import re

punctuation_removed_text = re.sub(r'[^\w\s]',' ',text)
punctuation_removed_text
# Out:
# 'india  officially the republic of india  hindi  bhārat gaṇarājya   26  is a country in south asia  it is the seventh largest country by area  the second most populous country  and the most populous democracy in the world  bounded by the indian ocean on the south  the arabian sea on the southwest  and the bay of bengal on the southeast  it shares land borders with pakistan to the west  f  china  nepal  and bhutan to the north  and bangladesh and myanmar to the east  in the indian ocean  india is in the vicinity of sri lanka and the maldives  its andaman and nicobar islands share a maritime border with thailand  myanmar  and indonesia  the nation s capital city is new delhi '

# %%
#stopword removal

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

allstopwords = stopwords.words('english')
stopword_removed_text = ''

for word in punctuation_removed_text.split():
  if word not in allstopwords:
    stopword_removed_text+=word+' '

stopword_removed_text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 'india officially republic india hindi bhārat gaṇarājya 26 country south asia seventh largest country area second populous country populous democracy world bounded indian ocean south arabian sea southwest bay bengal southeast shares land borders pakistan west f china nepal bhutan north bangladesh myanmar east indian ocean india vicinity sri lanka maldives andaman nicobar islands share maritime border thailand myanmar indonesia nation capital city new delhi '

# %%
#spelling correction

# !pip install textblob
from textblob import TextBlob

spell_correct_text=''

for word in stopword_removed_text.split():
  spell_correct_text+=str(TextBlob(word).correct()) + ' '

spell_correct_text
# Out:
# 'india officially republic india hind brat gaṇarājya 26 country south asia seventh largest country area second populous country populous democracy world bounded indian ocean south arabian sea southwest bay bengal southeast shares land borders parisian west f china near human north bangladesh myanmar east indian ocean india vicinity sir lank maladies adamant nicobar islands share maritime border thailand myanmar indonesia nation capital city new delhi '

# %%
# stemming

from nltk.stem import PorterStemmer
st = PorterStemmer()
stemmed_text = ''

for word in spell_correct_text.split():
  stemmed_text+=st.stem(word)+' '

stemmed_text
# Out:
# 'india offici republ india hind brat gaṇarājya 26 countri south asia seventh largest countri area second popul countri popul democraci world bound indian ocean south arabian sea southwest bay bengal southeast share land border parisian west f china near human north bangladesh myanmar east indian ocean india vicin sir lank maladi adam nicobar island share maritim border thailand myanmar indonesia nation capit citi new delhi '

# %%
#wordcloud


from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# %%
stemmed_text.split()
# Out:
# ['india',
#  'offici',
#  'republ',
#  'india',
#  'hind',
#  'brat',
#  'gaṇarājya',
#  '26',
#  'countri',
#  'south',
#  'asia',
#  'seventh',
#  'largest',
#  'countri',
#  'area',
#  'second',
#  'popul',
#  'countri',
#  'popul',
#  'democraci',
#  'world',
#  'bound',
#  'indian',
#  'ocean',
#  'south',
#  'arabian',
#  'sea',
#  'southwest',
#  'bay',
#  'bengal',
#  'southeast',
#  'share',
#  'land',
#  'border',
#  'parisian',
#  'west',
#  'f',
#  'china',
#  'near',
#  'human',
#  'north',
#  'bangladesh',
#  'myanmar',
#  'east',
#  'indian',
#  'ocean',
#  'india',
#  'vicin',
#  'sir',
#  'lank',
#  'maladi',
#  'adam',
#  'nicobar',
#  'island',
#  'share',
#  'maritim',
#  'border',
#  'thailand',
#  'myanmar',
#  'indonesia',
#  'nation',
#  'capit',
#  'citi',
#  'new',
#  'delhi']

# %%
words=stemmed_text.split() 

print(words)                 

wordcloud = WordCloud(width=1000,height=500).generate(" ".join(words))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ['india', 'offici', 'republ', 'india', 'hind', 'brat', 'gaṇarājya', '26', 'countri', 'south', 'asia', 'seventh', 'largest', 'countri', 'area', 'second', 'popul', 'countri', 'popul', 'democraci', 'world', 'bound', 'indian', 'ocean', 'south', 'arabian', 'sea', 'southwest', 'bay', 'bengal', 'southeast', 'share', 'land', 'border', 'parisian', 'west', 'f', 'china', 'near', 'human', 'north', 'bangladesh', 'myanmar', 'east', 'indian', 'ocean', 'india', 'vicin', 'sir', 'lank', 'maladi', 'adam', 'nicobar', 'island', 'share', 'maritim', 'border', 'thailand', 'myanmar', 'indonesia', 'nation', 'capit', 'citi', 'new', 'delhi']
